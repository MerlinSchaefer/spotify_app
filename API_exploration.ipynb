# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.util as util
from pathlib import Path

# %%
path = Path("C:/Users/ms101/OneDrive/DataScience_ML/projects/spotify_app")

# %%
with open(path / "client_s.txt") as f:
    content = f.readlines()
content = [x.strip() for x in content]

# %%
client_id = content[0]
client_secret = content[1]

# %%
with open(path / "usernames.txt") as f:
    usernames = f.readlines()
usernames = [x.strip() for x in usernames]

# %%
username1 = usernames[0]
username2 = usernames[1]

# %%
scope = "user-library-read user-read-recently-played user-top-read playlist-modify-public playlist-read-private"

# %%
redirect_uri = "https://developer.spotify.com/dashboard/applications/4a4e029d299a4241873db8300038bf0a"

# %%
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, 
                                                      client_secret=client_secret)

sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
token = util.prompt_for_user_token(username1, scope, client_id, client_secret, redirect_uri)

if token:
    sp = spotipy.Spotify(auth=token)
else:
    print("Can't get token for", username1)

# %%
import pandas as pd

sourcePlaylistID = '16xXJ6LbpSmdCaM7jVVrtX'
sourcePlaylist = sp.user_playlist(username1, sourcePlaylistID);
tracks = sourcePlaylist["tracks"];
songs = tracks["items"];

track_ids = []
track_names = []

for i in range(0, len(songs)):
    if songs[i]['track']['id'] != None: # Removes the local tracks in your playlist if there is any
        track_ids.append(songs[i]['track']['id'])
        track_names.append(songs[i]['track']['name'])

features = []
for i in range(0,len(track_ids)):
    audio_features = sp.audio_features(track_ids[i])
    for track in audio_features:
        features.append(track)
        
playlist_df = pd.DataFrame(features, index = track_names)

# %%
playlist_df
# Out:
#                                                     danceability  energy  key  \
# What If (feat. Gizzle)                                     0.519   0.528    4
# Antisocial (with Travis Scott)                             0.716   0.823    5
# Nicht die Musik                                            0.633   0.714    8
# Heathens                                                   0.737   0.476    4
# Time - Edit                                                0.665   0.703    8
# ...                                                          ...     ...  ...
# Periscope (feat. Skylar Grey)                              0.593   0.711    7
# Avalanche                                                  0.426   0.934    7
# Out of the Black                                           0.520   0.981    2
# The Rains of Castamere (from Game of Thrones - ...         0.255   0.157    2
# Billie Jean                                                0.920   0.654   11
#
#                                                     loudness  mode  \
# What If (feat. Gizzle)                                -8.419     0
# Antisocial (with Travis Scott)                        -5.313     0
# Nicht die Musik                                       -5.839     0
# Heathens                                              -5.825     0
# Time - Edit                                           -3.885     1
# ...                                                      ...   ...
# Periscope (feat. Skylar Grey)                         -6.593     0
# Avalanche                                             -4.063     0
# Out of the Black                                      -2.750     1
# The Rains of Castamere (from Game of Thrones - ...   -14.552     0
# Billie Jean                                           -3.051     0
#
#                                                     speechiness  acousticness  \
# What If (feat. Gizzle)                                   0.0907      0.135000
# Antisocial (with Travis Scott)                           0.0495      0.132000
# Nicht die Musik                                          0.1530      0.004950
# Heathens                                                 0.0262      0.090800
# Time - Edit                                              0.0700      0.128000
# ...                                                         ...           ...
# Periscope (feat. Skylar Grey)                            0.0301      0.283000
# Avalanche                                                0.0685      0.000030
# Out of the Black                                         0.0906      0.000867
# The Rains of Castamere (from Game of Thrones - ...       0.0312      0.368000
# Billie Jean                                              0.0401      0.023600
#
#                                                     instrumentalness  \
# What If (feat. Gizzle)                                      0.000000
# Antisocial (with Travis Scott)                              0.000000
# Nicht die Musik                                             0.000000
# Heathens                                                    0.000054
# Time - Edit                                                 0.000000
# ...                                                              ...
# Periscope (feat. Skylar Grey)                               0.000000
# Avalanche                                                   0.008900
# Out of the Black                                            0.001770
# The Rains of Castamere (from Game of Thrones - ...          0.213000
# Billie Jean                                                 0.015800
#
#                                                     liveness  valence  \
# What If (feat. Gizzle)                                0.1740    0.164
# Antisocial (with Travis Scott)                        0.3610    0.910
# Nicht die Musik                                       0.0933    0.265
# Heathens                                              0.0968    0.555
# Time - Edit                                           0.1150    0.257
# ...                                                      ...      ...
# Periscope (feat. Skylar Grey)                         0.2080    0.250
# Avalanche                                             0.1130    0.285
# Out of the Black                                      0.1970    0.633
# The Rains of Castamere (from Game of Thrones - ...    0.3050    0.204
# Billie Jean                                           0.0359    0.847
#
#                                                       tempo            type  \
# What If (feat. Gizzle)                              129.835  audio_features
# Antisocial (with Travis Scott)                      151.957  audio_features
# Nicht die Musik                                     191.998  audio_features
# Heathens                                             90.028  audio_features
# Time - Edit                                          97.968  audio_features
# ...                                                     ...             ...
# Periscope (feat. Skylar Grey)                       121.960  audio_features
# Avalanche                                           160.077  audio_features
# Out of the Black                                    158.937  audio_features
# The Rains of Castamere (from Game of Thrones - ...   92.911  audio_features
# Billie Jean                                         117.046  audio_features
#
#                                                                         id  \
# What If (feat. Gizzle)                              7swwxTs8Ra32hrsnWWgIyZ
# Antisocial (with Travis Scott)                      1DhRbox3xkceP64k3JeYfW
# Nicht die Musik                                     6Mf8R6pht49aK7uttrc0lu
# Heathens                                            3vZM2544ETmOCCHuBPZRzm
# Time - Edit                                         68Vm2W4oURsPV3121vUZgB
# ...                                                                    ...
# Periscope (feat. Skylar Grey)                       5ADZl5Ty5O9EGy8ABSqXCg
# Avalanche                                           4EyPadLFhtWojU7mkT5hqT
# Out of the Black                                    1INksmStBpxdNlBzwGUvsg
# The Rains of Castamere (from Game of Thrones - ...  4vZXdEfk0767LAcIBol4Un
# Billie Jean                                         5ChkMS8OtdzJeqyybCc9R5
#
#                                                                                      uri  \
# What If (feat. Gizzle)                              spotify:track:7swwxTs8Ra32hrsnWWgIyZ
# Antisocial (with Travis Scott)                      spotify:track:1DhRbox3xkceP64k3JeYfW
# Nicht die Musik                                     spotify:track:6Mf8R6pht49aK7uttrc0lu
# Heathens                                            spotify:track:3vZM2544ETmOCCHuBPZRzm
# Time - Edit                                         spotify:track:68Vm2W4oURsPV3121vUZgB
# ...                                                                                  ...
# Periscope (feat. Skylar Grey)                       spotify:track:5ADZl5Ty5O9EGy8ABSqXCg
# Avalanche                                           spotify:track:4EyPadLFhtWojU7mkT5hqT
# Out of the Black                                    spotify:track:1INksmStBpxdNlBzwGUvsg
# The Rains of Castamere (from Game of Thrones - ...  spotify:track:4vZXdEfk0767LAcIBol4Un
# Billie Jean                                         spotify:track:5ChkMS8OtdzJeqyybCc9R5
#
#                                                                                            track_href  \
# What If (feat. Gizzle)                              https://api.spotify.com/v1/tracks/7swwxTs8Ra32...
# Antisocial (with Travis Scott)                      https://api.spotify.com/v1/tracks/1DhRbox3xkce...
# Nicht die Musik                                     https://api.spotify.com/v1/tracks/6Mf8R6pht49a...
# Heathens                                            https://api.spotify.com/v1/tracks/3vZM2544ETmO...
# Time - Edit                                         https://api.spotify.com/v1/tracks/68Vm2W4oURsP...
# ...                                                                                               ...
# Periscope (feat. Skylar Grey)                       https://api.spotify.com/v1/tracks/5ADZl5Ty5O9E...
# Avalanche                                           https://api.spotify.com/v1/tracks/4EyPadLFhtWo...
# Out of the Black                                    https://api.spotify.com/v1/tracks/1INksmStBpxd...
# The Rains of Castamere (from Game of Thrones - ...  https://api.spotify.com/v1/tracks/4vZXdEfk0767...
# Billie Jean                                         https://api.spotify.com/v1/tracks/5ChkMS8OtdzJ...
#
#                                                                                          analysis_url  \
# What If (feat. Gizzle)                              https://api.spotify.com/v1/audio-analysis/7sww...
# Antisocial (with Travis Scott)                      https://api.spotify.com/v1/audio-analysis/1DhR...
# Nicht die Musik                                     https://api.spotify.com/v1/audio-analysis/6Mf8...
# Heathens                                            https://api.spotify.com/v1/audio-analysis/3vZM...
# Time - Edit                                         https://api.spotify.com/v1/audio-analysis/68Vm...
# ...                                                                                               ...
# Periscope (feat. Skylar Grey)                       https://api.spotify.com/v1/audio-analysis/5ADZ...
# Avalanche                                           https://api.spotify.com/v1/audio-analysis/4EyP...
# Out of the Black                                    https://api.spotify.com/v1/audio-analysis/1INk...
# The Rains of Castamere (from Game of Thrones - ...  https://api.spotify.com/v1/audio-analysis/4vZX...
# Billie Jean                                         https://api.spotify.com/v1/audio-analysis/5Chk...
#
#                                                     duration_ms  \
# What If (feat. Gizzle)                                   252947
# Antisocial (with Travis Scott)                           161747
# Nicht die Musik                                          118871
# Heathens                                                 195743
# Time - Edit                                              230611
# ...                                                         ...
# Periscope (feat. Skylar Grey)                            216771
# Avalanche                                                262013
# Out of the Black                                         240572
# The Rains of Castamere (from Game of Thrones - ...       143933
# Billie Jean                                              293827
#
#                                                     time_signature
# What If (feat. Gizzle)                                           4
# Antisocial (with Travis Scott)                                   4
# Nicht die Musik                                                  4
# Heathens                                                         4
# Time - Edit                                                      4
# ...                                                            ...
# Periscope (feat. Skylar Grey)                                    4
# Avalanche                                                        4
# Out of the Black                                                 4
# The Rains of Castamere (from Game of Thrones - ...               4
# Billie Jean                                                      4
#
# [66 rows x 18 columns]
